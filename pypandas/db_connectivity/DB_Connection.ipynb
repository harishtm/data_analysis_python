# %%
import pandas as pd
import sqlalchemy

# %% [markdown]
# __Establish the database connection__

# %%
engine = sqlalchemy.create_engine('mysql+mysqlconnector://root:root@localhost/digitmarketadmindb')

# %% [markdown]
# __Data can be loaded via the created engine__

# %%
df = pd.read_sql_table("product_product", engine)

# %%
df
# Out:
#     id                                        title  \
# 0    9
# 1   10
# 2   19                                       asdasd
# 3   20                        uydiasdiasidaisdiasdi
# 4   21  oioopopoppppppppppppppppppppppppppppppppppp
# 5   22                                        90909
# 6   23                                         weqe
# 7   24                                       asdasd
# 8   25                                       asdasd
# 9   26                                      1234567
# 10  27                              111111111111111
# 11  29                                          222
# 12  30                                         1234
# 13  31                                      2221111
# 14  32                                     12345678
# 15  33                                     12345678
# 16  34                                  12345678111
# 17  35                            asdasdasd2qqeqwwe
# 18  36                                      2112213
# ...

# %%
df = pd.read_sql_table("customer_customercontactbasicinformation", engine)

# %%
df = pd.read_sql_table("servicemarket_servicecomments", engine)

# %%
df
# Out:
#             id  commentRating  \
# 0            1            2.0
# 1            2            5.0
# 2            3            4.0
# 3            4            5.0
# 4            5            3.0
# 5            6            2.0
# 6            7            3.0
# 7            8            4.0
# 8            9            4.0
# 9           10            4.0
# 10          11            5.0
# 11          12            5.0
# 12          13            5.0
# 13          14            5.0
# 14          15            0.0
# 15          16            0.0
# 16          17            4.0
# 17          18            3.0
# 18          19            3.0
# 19          20            4.0
# 20          21            5.0
# 21          22            5.0
# 22          23            4.0
# 23          24            4.0
# 24          25            5.0
# 25          26            1.0
# 26          27            1.0
# 27          28            1.0
# 28          29            3.0
# 29          30            4.0
# ...

# %%
df.shape
# Out:
# (477179, 9)
